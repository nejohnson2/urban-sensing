# %% [markdown]
# # Rapid Prototyping of Urban Sensors
# ### Bottom-up Techniques for Building and Deploying Sensors
#
# ---
# <div style="float: right; margin-left: 20px; margin-bottom: 10px;">
# <img src="sensor.jpg" style='width: 450px;'>
# <p style="text-align: right; margin-top: 0px; font-style: italic;">sensor-controlled pedestrian crossing</p>
# </div>
#
# **Instructor :** Nicholas Johnson - nicholas.johnson@nyu.edu  <br />
# **Lab Assistant :** Mohit Sanjay Sharma <br />
# **Date/Time/Location :** TBD
#
# ### Course Description
# Urban science revolves around using data to explore and answer questions about cities. Often this data is available through a variety of sources and is easily obtainable. In some cases, however, the necessary data may not exist and the need for building and deploying sensors becomes necessary. Simultaneously, the recent onset of new low-cost technologies, the ubiquitous use of wifi and cellular communication and a drive for smart and sustainable cities have opened the possibility for rapid prototyping and deploying of sensors in urban spaces. Given this context, what can we learn about cities from the deployment of sensors and how can we leverage these technologies to better understand a city's infrastructure, environment and people?
#
# This course will introduce the fundamentals of prototyping sensors and the techniques and considerations for deployment in urban spaces. Through the course students will learn the basics of electricity, programming microcontrollers, reading analog/digital inputs and wireless data transmission. Students will be challenged to not only explore sensor integration and data collection but to also think more broadly on how deploying sensors can help quantify and understand an urban issues.

# %% [markdown]
# ### Schedule
# - Class 1 - Introduction to Urban Sensing
#     - 30min Class introduction
#         - Introductions
#         - Course Structure
#         - Class Goal, Expectations etc...
#     - 60min About Urban Sensing
#         - Urban sensing vs Smart Cities
#         - What to measure? Infrastructure, environment, people - Libelium
#         - Defining Sensor Society [conference link](http://cccs.uq.edu.au/sensor-society-audio)
#         - Scale of sensors: what are we talking about?
#         - Remote Sensing
#         - Data Journalism
#     - 10min Break
#     - 60min Intro to Electronics (Mohit)
#         - Electricity, circuits, electrical components, tools etc..
#     - 20min setting up Arduino, Homework
#     > **Homework: Observing the city** - 1) Observe and document technologies(sensors) in the city. 2) Observe and document your interactions with city infrastructure(streets, power, communication, waste, sewage etc..).  Does it work?  Is it measured and if so how?  Think about the systems that enable it to work.  This doesnt necessarily mean to look for things to 'fix'.  Look for things that will help to understand.  3) Reading.  Send a link to your blog post.
#
# - Class 2 - Microcontrolers(Arudino)
#     - 30-45min Reading/Homework discussion
#     - 10min
#     - 60min Programming Arduino (Nick)
#         - analog input
#         - digital input/output
#     - 60min Electronic components 2 (Mohit)
#         - In class lab: Build a power regulator
#     > **Homework** - Use regulated power supply to control LED brightness
#
# - Class 3 - Sensors
#     - 20min Homework Discussion
#     - 60min - Sensors
#         - Motion, light, distance, touch etc..
#     - 10min
#     - 60min (demo)
#         - sensor interfacing, datasheets
#         - calibration/resolution
#         - where to buy
#     - 30min - Midterm Project Discussion/Homework
#         - start brain storming
#     > **Homework:** - Choose a sensor to experiment with.  Purchase the sensor, get it working, and contemplate applications for the sensor.  We will be creating a database of these sensors.  Consider the project to be a 'sensor review'.
#     > **Reading:** -
#
# - Class 4 - Small Data
#     - 30min Reading/Homework discussion
#     - 60min Case Study: Gowanus Canal - Liz Barry, Eymund Diegel, Leif
#     - 60min Role of small data
#         - Public Lab
#         - PL Tools
#         - crowdsourcing
#
#     > **Homework:** - Work on your midterm project.  You will have five minutes to present your sensor next week.
#
# - Class 5 - Ensuring Data Quality/ Field Trip to QC
#     - 90min Midterm project presentations
#     - 10min Break
#     - 60min Lab: Time and Location Awareness (Data Logging and Location)
#     - 20min Final Project Groups/Discussion
#     > **Homework:** - Meet with your group.  Brainstorm and begin discussing ideas for the final project.  Discuss the goals and the questions you are trying to answer.  Prepare a short presentation(5min) about your idea(s) to be discussed in class next time.
#
# - Class 6 - Wireless Communication
#     - 60min Final Project Discussion
#     - 10min Break
#     - 60min Wireless Technologies (data transmission) (Mohit)
#         - GSM/Bluetooth/Wifi/Radio
#     - In class lab: Connecting over GSM
#     > ** Homework: ** - Finalize your project idea.  Create a data collection flow chart discussing which components you will be using, how they will work together, what you will be collecting etc...
#
# - Class 7 - To the web!
#     - 60min Final Project Discussion
#     - 10min Break
#     - 60min IOT (Nick)
#         - web-based tools (Twilio, temboo, Xively)
#     - 40min In Class Lab: serial to node.js(or Tornado) (Mohit)
# - Class 8 - Considerations for deployment (Guest Lecture Charlie)
#     - 60min Discuss final projects
#     - 60min 3D prototyping
#         - Power usage, building boxes, data storage
# - Class 9 - Review and in-class workshops
# - Class 10 - Final Project Presentations

# %% [markdown]
# ### Course Materials
#
# Student are required to have an Arduino kit.  These will be used by students individually over the first 5 weeks of the class.  Other sensors student can purchase online from a variety of sites (Adafruit, Sparkfun, Seeed Studio).
#
# *Please remember shipping will take time, parts will fail, orders will be wrong etc...    **Order early!!!** *

# %% [markdown]
# ### Final Project
#
# Working in groups, students will identify an urban issue and devise a method of collecting data to gain insight on that issue.  The means by which data is collected can vary from continuous real-time collection to discrete sampling and will be left to the students to decide how best to approach the issue.
#
# The final project should contain this workflow:
#
# 1. Clearly identify an urban problem and determine what data could help you better understand that problem.
# 2. Design a data collection system
#     - students should be able to clearly identify the desired data, how the data will help understand/evaluate the problem and the necessary considerations for deploying the device.
#
# 3. Build and deploy prototype sensor
#     - this should be considered and 'experiment' - a way to test and see if you sensor and system foc collecting data actually works and helps clarify the proposed problem
#
# Students will be require to give a final presentation about their project explaining the above steps.  Students should describe their methods, explain how they came to their conclusions and propose their (potential) next steps for the project.

# %% [markdown]
# ### Course Evaluation
#
# Students will be graded on the following.
#
# **Documentation of Weekly Assignments/Labs (25%) ** - Students are expected to document all of their work through weekly blog posts, github postings etc... This documentation should be available on the web and will link to the course website.
#
# **Midterm Project (10%)** - Midterm projects will done individual and should demonstrate the students' understanding of class concepts.  Students will have 5mins to present their work to the class.
#
# **Final Project (35%)** - Final projects will be conducted in groups.  The group is expected to meet the project requirements (as specified below) as well as present their work to the class.  Groups will have 15mins to present followed by questions.
#
# **Attendence (30%)** - Attendence at all classes is requied unless permission is specifically requested from the professor for legitimate reasons.

# %% [markdown]
# ### Readings
#
# - *Physical Computing: Sensing and Controlling the Physical World with Computers*, Dan O’Sullivan and Tom Igoe ©2004, Thomson Course Technology PTR; ISBN: 159200346X
#
# ### Papers
# - [People Centric Urban Sensing](http://sensorlab.cs.dartmouth.edu/pubs/metrosense06.pdf)
# - [LESS IS MORE: THE ROLE OF SMALL DATA FOR GOVERNANCE IN THE 21ST CENTURY](http://i.publiclab.org/system/images/photos/000/008/189/original/CEGOV_Digital_Governance_2014_Chapter6.pdf)
# - [Community-based Research Partnerships: Challenges and Opportuities](http://link.springer.com/article/10.1093%2Fjurban%2Fjti034?LI=true)
# - [The Promise of Small Data](http://techpresident.com/news/24176/backchannel-promise-small-data)
# - [Sensor Mania! The Internet of Things, Wearable Computing, Objective Metrics, and the Quantified Self 2.0](http://www.mdpi.com/2224-2708/1/3/217)
#
# ### Web
# - [Remote Controls, Switchboards, Dashboards, War Rooms: The Cybernetics DNA of Smart Cities](https://medium.com/@dangerbui/remote-controls-and-dashboards-is-the-responsive-city-an-authoritarian-w-7617e8a83d9)
# - [Two Approaches to Urban Sensing: Synoptic vs Ground Truth](https://medium.com/@anthonymobile/two-approaches-to-urban-sensing-synoptic-vs-ground-truth-b584a7285ecb) - Anthony Townsend
# - [Beddit](http://www.beddit.com/wp-content/uploads/2014/10/Beddit_Science_Leaflet_A4_HR.pdf)

# %% [markdown]
# ### Resources
#
# - Syllabus for: [Rest of You](https://itp.nyu.edu/classes/roy-spring2014/autonomic-sensors/)
# - Syllabus for: [Quantified Self: About Town](http://senseandscale.info/)
# - ITP physical computing [homepage](https://itp.nyu.edu/physcomp/)
# - [Bio-sensing: by Sean Montgomery](http://produceconsumerobot.com/biosensing/)
# - cusp-sensors google group!

# %% [markdown]
# ### Others
#
# - [Ted Talk - Eduardo Paes: The 4 Commandments of Cities](https://www.ted.com/talks/eduardo_paes_the_4_commandments_of_cities?language=en)
